# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Task1_3_Corrected.csv").drop("Unnamed: 0", axis=1)
df.head()
# Out:
#    Number_PP                           Name                      Full_name  \
# 0          1            (o) Ламинат Symbio             (o) Ламинат Symbio
# 1          2         (o) Ламинат Synchrotec         (o) Ламинат Synchrotec
# 2          3   (о) Коврики влаговпитывающие   (о) Коврики влаговпитывающие
# 3          4             (о) Ковролин Ideal             (о) Ковролин Ideal
# 4          5  (о) Ковролин Синтелон (свотч)  (о) Ковролин Синтелон (свотч)
#
#    Code Unit_of_reconciliation Additional_characteristics  \
# 0  1920                     м2                        Нет
# 1  1921                     м2                        Нет
# 2  2037                     шт                        Нет
# 3  2020                     шт                        Нет
# 4  2390                     шт                        Нет
#
#                   Owners_name   Kind  Article Weight  ... Nomenclature_group  \
# 0                      Symbio  Товар     1920    Нет  ...             Товары
# ...

# %%
df = df.drop(["Code", "Unit_of_reconciliation", "Additional_characteristics", "Article", "Weight", "Accounting_characteristics", "Storage_unit", "VAT_rate", "Service", "Nomenclature_group", "Sharto", "Main_supplier", "Main_supplier_object", "Comment", "Predefined", "Currency"], axis=1)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-270930e520d2> in <module>
# ----> 1 df = df.drop(["Code", "Unit_of_reconciliation", "Additional_characteristics", "Article", "Weight", "Accounting_characteristics", "Storage_unit", "VAT_rate", "Service", "Nomenclature_group", "Sharto", "Main_supplier", "Main_supplier_object", "Comment", "Predefined", "Currency"], axis=1)
#       2 df.head()
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4160                 weight  1.0     0.8
#    4161         """
# -> 4162         return super().drop(
#    4163             labels=labels,
#    4164             axis=axis,
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df.to_csv("PickedKBestNonLabeled.csv")
