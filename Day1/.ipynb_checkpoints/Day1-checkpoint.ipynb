# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Превращаем цену в тип float64

# %%
a = pd.read_excel("DataSet2021Spring_ОСНОВНОЙ.xlsx")
a = a.astype({'Price': 'float64'})

# %% [markdown]
# Соединяем цену с

# %%
print(a.values[0][24])
for i in range(0, len(a.values)):
    temp = str(a.values[i][24])
    temp2 = str(a.values[i][25])
    if (temp != 'nan' and temp2 != 'None'):
        tmp = a.values[i]
        tmp[20] += tmp[21]*(10**(-len(str(tmp[21]))))
        tmp = np.delete(tmp, 21)
        a.loc[i] = np.append(tmp, None)
# Out:
# 16

# %%
a.loc[0][22]
# Out:
# 84276

# %%
for i in range(0, len(a.values)):
    temp = str(a.values[i][24])
    if (temp != 'nan' and temp != 'None'):
        tmp = a.values[i]
        tmp[22] += tmp[23]*(10**(-len(str(tmp[23]))))
        tmp = np.delete(tmp, 23)
        a.loc[i] = np.append(tmp, None)

# %%
a.head()
a.drop(columns=['Unnamed: 24', 'Unnamed: 25'])
# Out:
#       Number_PP                                Name  \
# 0             1                 (o) Ламинат Symbio
# 1             2              (o) Ламинат Synchrotec
# 2             3        (о) Коврики влаговпитывающие
# 3             4                  (о) Ковролин Ideal
# 4             5       (о) Ковролин Синтелон (свотч)
# ...         ...                                 ...
# 1152       2201                     Элемент питания
# 1153       2202                            Этикетки
# 1154       2203                  Юридические услуги
# 1155       2204  Я Дорожки влаговпитывающие (архив)
# 1156       2205   ЯАРХИВ Ковровые покрытия СИНТЕЛОН
#
#                                Full_name  Code Unit_of_reconciliation  \
# 0                    (o) Ламинат Symbio   1920                     м2
# 1                 (o) Ламинат Synchrotec  1921                     м2
# 2           (о) Коврики влаговпитывающие  2037                     шт
# 3                     (о) Ковролин Ideal  2020                     шт
# 4          (о) Ковролин Синтелон (свотч)  2390                     шт
# ...                                  ...   ...                    ...
# 1152                     Элемент питания  2508                     шт
# 1153                            Этикетки  1544                     шт
# 1154                  Юридические услуги  2002                     шт
# 1155  Я Дорожки влаговпитывающие (архив)  1918                     м2
# 1156                                 NaN  1911                    NaN
#
#      Additional_characteristics                 Owners_name      Kind  \
# 0                           Нет                      Symbio     Товар
# 1                           Нет                  Synchrotec     Товар
# 2                           Нет    Коврики влаговпитывающие     Товар
# 3                           Нет              Ковролин Ideal     Товар
# 4                           Нет  Ковролин СИНТЕЛОН (Сербия)     Товар
# ...                         ...                         ...       ...
# 1152                        Нет                   Материалы  Материал
# 1153                        Нет                   Материалы  Материал
# 1154                        Нет                      Услуги    Услуга
# 1155                        Нет    Коврики влаговпитывающие     Товар
# 1156                        Нет                    Ковролин     Товар
#
#       Article Weight  ... Nomenclature_group      Sharto     Main_supplier  \
# 0        1920    Нет  ...             Товары  1619658683               NaN
# 1        1921    Нет  ...             Товары   162653771               NaN
# 2        2037    Нет  ...             Товары   162653771       ОПУС ТД ООО
# 3        2020    Нет  ...             Товары  1993477958       ОПУС ТД ООО
# 4        2390    Нет  ...             Товары  1993477958  Монарх МБК-М ООО
# ...       ...    ...  ...                ...         ...               ...
# 1152     2508    Нет  ...             Товары  3533952240               NaN
# 1153     1544    Нет  ...             Товары  3533952240               NaN
# 1154     2002    Нет  ...             Товары  3533952240               NaN
# 1155     1918    Нет  ...             Товары  3450882367       ОПУС ТД ООО
# 1156     1911    Нет  ...                NaN  3450882367               NaN
#
#      Main_supplier_object Comment  Predefined   Price Qty_stock  \
# 0                     Нет     NaN         Нет  188.96       446
# 1                     Нет     NaN         Нет   95.73       720
# 2                     Нет     NaN         Нет   99.83       426
# 3                     Нет     NaN         Нет   93.28       648
# 4                     Нет     NaN         Нет   52.33       905
# ...                   ...     ...         ...     ...       ...
# 1152                  Нет     NaN         Нет    2.36       570
# 1153                  Нет     NaN         Нет    5.39        44
# 1154                  Нет     NaN         Нет   97.74       992
# 1155                  Нет     NaN         Нет   59.93       633
# 1156                  Нет     NaN         Нет   24.49       604
#
#      Remaining_amount Currency
# 0            84276.16      Руб
# 1            68925.60      Руб
# 2            42527.58      Руб
# 3            60445.44      Руб
# 4            47358.65      Руб
# ...               ...      ...
# 1152          1345.20      Руб
# 1153           237.16      Руб
# 1154         96958.80      Руб
# 1155         37935.69      Руб
# 1156         14791.96      Руб
#
# [1157 rows x 24 columns]

# %%
a.to_csv("Test1.csv")
